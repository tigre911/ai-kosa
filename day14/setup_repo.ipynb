# %%
from google.colab import drive
import os

# Google Drive를 /content/gdrive에 마운트
drive.mount('/content/gdrive')

# ~/work 디렉토리를 생성
os.makedirs('/content/work', exist_ok=True)

# Google Drive를 ~/work에 마운트
# !ln -s /content/gdrive/MyDrive/ /content/work
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/work/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# !git clone https://weable72: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@github.com/weable-kosa/kosa-ict-genai-2025-hyuandai.git
# Out:
# Cloning into 'kosa-ict-genai-2025-hyuandai'...
# remote: Enumerating objects: 26638, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 26638 (delta 78), reused 112 (delta 57), pack-reused 26479 (from 3)
# Receiving objects: 100% (26638/26638), 470.83 MiB | 10.63 MiB/s, done.
# Resolving deltas: 100% (9084/9084), done.
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# ^C

# %%
# %cd kosa-ict-genai-2025-hyun
# Out:
# /content/gdrive/MyDrive/kosa-ict-genai-2025-2nd

# %%
# !git add ./src/exercise/bardroh/day02/my_new_notebook.ipynb
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git config --global user.email "bardroh@weable.ai"
# !git config --global user.name "Bard K. Roh"

# %%
# !git commit -m 'add new notebook'
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
